# %%
import pynance as pn
import yfinance as yf
import pandas as pd
import sys

# %%
sys.path.append('../scripts')
from eda_finance_data import load_financial_data, basic_eda

# %%
# Define file paths
file_paths = {
    'AAPL': '../data/yfinance_data/AAPL_historical_data.csv',
    'AMZN': '../data/yfinance_data/AMZN_historical_data.csv',
    'GOOG': '../data/yfinance_data/GOOG_historical_data.csv',
    'META': '../data/yfinance_data/META_historical_data.csv',
    'MSFT': '../data/yfinance_data/MSFT_historical_data.csv',
    'NVDA': '../data/yfinance_data/NVDA_historical_data.csv',
    'TSLA': '../data/yfinance_data/TSLA_historical_data.csv'
}

# %%
# Load and EDA
dataframes = load_financial_data(file_paths)
summary = basic_eda(dataframes)
# Out:
# ================================== AAPL ===========================================
# Shape: (10998, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date          Open          High           Low         Close  \
# count        10998  10998.000000  10998.000000  10998.000000  10998.000000
# unique       10998           NaN           NaN           NaN           NaN
# top     2024-07-30           NaN           NaN           NaN           NaN
# freq             1           NaN           NaN           NaN           NaN
# mean           NaN     22.299160     22.539055     22.068367     22.312754
# std            NaN     46.003685     46.496031     45.540929     46.037660
# min            NaN      0.049665      0.049665      0.049107      0.049107
# 25%            NaN      0.299107      0.303710      0.290179      0.298549
# 50%            NaN      0.531250      0.537946      0.522321      0.531250
# 75%            NaN     20.204196     20.389554     19.998036     20.196160
# max            NaN    236.479996    237.229996    233.089996    234.820007
#
#            Adj Close        Volume     Dividends  Stock Splits
# count   10998.000000  1.099800e+04  10998.000000  10998.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean       21.494496  3.180806e+08      0.000752      0.001546
# std        45.561916  3.354523e+08      0.011753      0.083663
# min         0.037857  0.000000e+00      0.000000      0.000000
# 25%         0.241840  1.132545e+08      0.000000      0.000000
# 50%         0.432079  2.057412e+08      0.000000      0.000000
# 75%        17.253029  3.985275e+08      0.000000      0.000000
# max       234.548523  7.421641e+09      0.250000      7.000000
#
# ================================== AMZN ===========================================
# Shape: (6846, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         6846  6846.000000  6846.000000  6846.000000  6846.000000
# unique        6846          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN    37.360464    37.801009    36.882561    37.351096
# std            NaN    53.756955    54.366449    53.087051    53.729913
# min            NaN     0.070313     0.072396     0.065625     0.069792
# 25%            NaN     2.070125     2.120625     2.040156     2.076750
# 50%            NaN     8.574500     8.666750     8.466500     8.591500
# 75%            NaN    50.453876    50.723249    50.059875    50.426500
# max            NaN   200.089996   201.199997   199.050003   200.000000
#
#           Adj Close        Volume  Dividends  Stock Splits
# count   6846.000000  6.846000e+03     6846.0   6846.000000
# unique          NaN           NaN        NaN           NaN
# top             NaN           NaN        NaN           NaN
# freq            NaN           NaN        NaN           NaN
# mean      37.351096  1.380713e+08        0.0      0.003944
# std       53.729913  1.382346e+08        0.0      0.246789
# min        0.069792  9.744000e+06        0.0      0.000000
# 25%        2.076750  6.505442e+07        0.0      0.000000
# 50%        8.591500  1.020650e+08        0.0      0.000000
# 75%       50.426500  1.567560e+08        0.0      0.000000
# max      200.000000  2.086584e+09        0.0     20.000000
#
# ================================== GOOG ===========================================
# Shape: (5020, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         5020  5020.000000  5020.000000  5020.000000  5020.000000
# unique        5020          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN    45.251315    45.728793    44.800587    45.274515
# std            NaN    43.338635    43.818298    42.918167    43.377299
# min            NaN     2.470490     2.534002     2.390042     2.490913
# 25%            NaN    13.034705    13.145415    12.881592    13.032090
# 50%            NaN    26.982210    27.194902    26.791387    27.005927
# 75%            NaN    60.215126    60.758375    59.811811    60.280252
# max            NaN   191.750000   193.309998   190.619995   192.660004
#
#           Adj Close        Volume    Dividends  Stock Splits
# count   5020.000000  5.020000e+03  5020.000000   5020.000000
# unique          NaN           NaN          NaN           NaN
# top             NaN           NaN          NaN           NaN
# freq            NaN           NaN          NaN           NaN
# mean      45.224493  1.157539e+08     0.000040      0.004583
# std       43.332534  1.497936e+08     0.002823      0.284034
# min        2.488082  1.584340e+05     0.000000      0.000000
# 25%       13.017277  2.733950e+07     0.000000      0.000000
# 50%       26.975230  5.585480e+07     0.000000      0.000000
# 75%       60.211734  1.425333e+08     0.000000      0.000000
# max      192.660004  1.650833e+09     0.200000     20.000000
#
# ================================== META ===========================================
# Shape: (2926, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         2926  2926.000000  2926.000000  2926.000000  2926.000000
# unique        2926          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN   179.557215   181.875331   177.317761   179.649453
# std            NaN   108.864895   110.256219   107.511134   108.906971
# min            NaN    22.990000    23.090000    22.670000    22.900000
# 25%            NaN    97.767502    98.772499    95.889997    97.382498
# 50%            NaN   166.870003   168.850006   164.210007   166.855003
# 75%            NaN   231.450005   234.934998   228.687504   232.424999
# max            NaN   542.349976   542.809998   528.359985   539.909973
#
#           Adj Close        Volume    Dividends  Stock Splits
# count   2926.000000  2.926000e+03  2926.000000        2926.0
# unique          NaN           NaN          NaN           NaN
# top             NaN           NaN          NaN           NaN
# freq            NaN           NaN          NaN           NaN
# mean     179.305921  2.872083e+07     0.000342           0.0
# std      108.755055  2.269811e+07     0.013070           0.0
# min       22.853037  5.467500e+06     0.000000           0.0
# 25%       97.182795  1.571308e+07     0.000000           0.0
# 50%      166.512825  2.176100e+07     0.000000           0.0
# 75%      231.948360  3.294468e+07     0.000000           0.0
# max      539.909973  3.654579e+08     0.500000           0.0
#
# ================================== MSFT ===========================================
# Shape: (9672, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         9672  9672.000000  9672.000000  9672.000000  9672.000000
# unique        9672          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN    58.402199    59.003071    57.784759    58.417683
# std            NaN    90.122302    90.958645    89.232546    90.146786
# min            NaN     0.088542     0.092014     0.088542     0.090278
# 25%            NaN     5.695313     5.770508     5.617188     5.695313
# 50%            NaN    27.304999    27.600000    27.085000    27.341875
# 75%            NaN    46.687500    47.099998    46.138672    46.657187
# max            NaN   467.000000   468.350006   464.459991   467.559998
#
#           Adj Close        Volume    Dividends  Stock Splits
# count   9672.000000  9.672000e+03  9672.000000   9672.000000
# unique          NaN           NaN          NaN           NaN
# top             NaN           NaN          NaN           NaN
# freq            NaN           NaN          NaN           NaN
# mean      52.719365  5.677678e+07     0.002982      0.001758
# std       90.066461  3.814123e+07     0.046524      0.057944
# min        0.055665  2.304000e+06     0.000000      0.000000
# 25%        3.511695  3.206982e+07     0.000000      0.000000
# 50%       19.145540  4.990225e+07     0.000000      0.000000
# 75%       38.339042  7.071788e+07     0.000000      0.000000
# max      466.718781  1.031789e+09     3.080000      2.000000
#
# ================================== NVDA ===========================================
# Shape: (6421, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         6421  6421.000000  6421.000000  6421.000000  6421.000000
# unique        6421          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN     6.207884     6.320466     6.085095     6.207702
# std            NaN    16.138328    16.424862    15.794914    16.118517
# min            NaN     0.034896     0.035547     0.033333     0.034115
# 25%            NaN     0.277500     0.286250     0.269500     0.276750
# 50%            NaN     0.457250     0.464750     0.450750     0.457000
# 75%            NaN     4.182500     4.235750     4.116500     4.175000
# max            NaN   139.800003   140.759995   132.419998   135.580002
#
#           Adj Close        Volume    Dividends  Stock Splits
# count   6421.000000  6.421000e+03  6421.000000   6421.000000
# unique          NaN           NaN          NaN           NaN
# top             NaN           NaN          NaN           NaN
# freq            NaN           NaN          NaN           NaN
# mean       6.181334  6.060791e+08     0.000025      0.003348
# std       16.121352  4.323482e+08     0.000316      0.142397
# min        0.031291  1.968000e+07     0.000000      0.000000
# 25%        0.253843  3.456350e+08     0.000000      0.000000
# 50%        0.427637  5.070000e+08     0.000000      0.000000
# 75%        4.130434  7.362000e+08     0.000000      0.000000
# max      135.580002  9.230856e+09     0.010000     10.000000
#
# ================================== TSLA ===========================================
# Shape: (3545, 9)
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Duplicated Rows: 0
# Summary Stats:
#                Date         Open         High          Low        Close  \
# count         3545  3545.000000  3545.000000  3545.000000  3545.000000
# unique        3545          NaN          NaN          NaN          NaN
# top     2024-07-30          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN    75.505658    77.159237    73.743492    75.487264
# std            NaN   102.530489   104.806516   100.051787   102.456615
# min            NaN     1.076000     1.108667     0.998667     1.053333
# 25%            NaN    11.516667    11.861333    11.216667    11.565333
# 50%            NaN    17.463333    17.688667    17.100000    17.459333
# 75%            NaN   161.880005   165.333328   158.360001   161.479996
# max            NaN   411.470001   414.496674   405.666656   409.970001
#
#           Adj Close        Volume  Dividends  Stock Splits
# count   3545.000000  3.545000e+03     3545.0   3545.000000
# unique          NaN           NaN        NaN           NaN
# top             NaN           NaN        NaN           NaN
# freq            NaN           NaN        NaN           NaN
# mean      75.487264  9.699708e+07        0.0      0.002257
# std      102.456615  7.866828e+07        0.0      0.097921
# min        1.053333  1.777500e+06        0.0      0.000000
# 25%       11.565333  4.770600e+07        0.0      0.000000
# 50%       17.459333  8.250600e+07        0.0      0.000000
# 75%      161.479996  1.228890e+08        0.0      0.000000
# max      409.970001  9.140820e+08        0.0      5.000000
